# %% [markdown]
# # Task 1:
# 1. Write a function to compute 5/0 and use try/except to catch the exceptions.
#
# ![image.png](attachment:image.png)

# %%
def divide(a, b):
    try:
        ans = a / b
    except Exception as e:
        print(e)
    else: 
        print(ans)
    
divide(10, 5)
divide(5, 0)
# Out:
# 2.0
# division by zero

# %% [markdown]
# 2. Implement a Python program to generate all sentences where subject is in ["Americans", "Indians"] and verb is in ["Play", "watch"] and the object is in ["Baseball","cricket"].
#
# ![image.png](attachment:image.png)

# %%
subjects=["Americans","Indians"]
verbs=["play","watch"]
objects=["Baseball","Cricket"]

for subject in subjects:
    for verb in verbs:
        for obj in objects:
            print(f'{subject} {verb} {obj}.')
# Out:
# Americans play Baseball.
# Americans play Cricket.
# Americans watch Baseball.
# Americans watch Cricket.
# Indians play Baseball.
# Indians play Cricket.
# Indians watch Baseball.
# Indians watch Cricket.

# %% [markdown]
# # Task 2:
# 1. Write a function so that the columns of the output matrix are powers of the input vector.
#
# ![image.png](attachment:image.png)

# %%
def generate_vandermonde_matrix(l, p=5, isdescending=False):
    if isdescending:
        return [[i**j for j in range(p, -1, -1)] for i in l]
    return [[i**j for j in range(p+1)] for i in l]

print('Ascending:')
print(generate_vandermonde_matrix([1,2,3,4,5], 3))
print('Descending:')
print(generate_vandermonde_matrix([1,2,3,4,5], 3, isdescending=True))
# Out:
# Ascending:
# [[1, 1, 1, 1], [1, 2, 4, 8], [1, 3, 9, 27], [1, 4, 16, 64], [1, 5, 25, 125]]
# Descending:
# [[1, 1, 1, 1], [8, 4, 2, 1], [27, 9, 3, 1], [64, 16, 4, 1], [125, 25, 5, 1]]
